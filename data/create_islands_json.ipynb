# %% [markdown]
# ## Create islands JSON

# %%
import pandas as pd
islands_table = pd.read_csv('tables/islands.csv', sep=';')
islands_table.reset_index(inplace=True, drop=True)

# %%
islands_table.to_json(r'islands.json', orient='index', force_ascii=False)
islands_table
# Out:
#                  nameEn              nameGer                         waters  \
# 0      Alexander Island   Alexander-I.-Insel              Bellingshausensee
# 1   Axel Heiberg Island  Axel Heiberg Island               Arktischer Ozean
# 2         Baffin Island          Baffininsel  Nordatlantik/Arktischer Ozean
# 3                  Bali                 Bali                Indischer Ozean
# 4          Banks Island           Banksinsel               Arktischer Ozean
# ..                  ...                  ...                            ...
# 63             Tenerife            Teneriffa             Atlantischer Ozean
# 64     Tierra del Fuego            Feuerland                    Südatlantik
# 65                Timor                Timor                Indischer Ozean
# 66     Vancouver Island     Vancouver Island              Pazifischer Ozean
# 67      Victoria Island       Victoria-Insel               Arktischer Ozean
#
# ...
